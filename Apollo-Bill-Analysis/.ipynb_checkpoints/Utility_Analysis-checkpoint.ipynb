# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### First Look

# %%
df = pd.read_csv("Consumers_2022_2024.csv")
df.head()
# Out:
#    ACCOUNT_NUMBER BILL_MONTH_YEAR INVOICE_DATE          BILL_PERIOD  \
# 0    1.000060e+11          Jan-22    1/20/2022  12/18/21 - 01/14/22
# 1    1.000060e+11          Feb-22    2/18/2022  01/15/22 - 02/15/22
# 2    1.000060e+11          Mar-22    3/22/2022  02/16/22 - 03/16/22
# 3    1.000060e+11          Apr-22    4/21/2022  03/17/22 - 04/14/22
# 4    1.000060e+11          May-22    5/20/2022  04/15/22 - 05/17/22
#
#    INVOICE_NUMBER                      ORG_NAME1  ORG_NAME2 ACCOUNT_NAME  \
# 0    2.010960e+11  MSU STUDENT HOUSING CO OP INC        NaN  C/O MSO SHC
# 1    2.010080e+11  MSU STUDENT HOUSING CO OP INC        NaN  C/O MSO SHC
# 2    2.012740e+11  MSU STUDENT HOUSING CO OP INC        NaN  C/O MSO SHC
# 3    2.011850e+11  MSU STUDENT HOUSING CO OP INC        NaN  C/O MSO SHC
# 4    2.010960e+11  MSU STUDENT HOUSING CO OP INC        NaN  C/O MSO SHC
#
#                                  SERVICE_ADDRESS  \
# 0  236 N HARRISON RD,EAST LANSING MI 48823-4141,
# ...

# %% [markdown]
# ### Now a Basic Usage Graph

# %%
# Assuming your data has a column 'BILL_MONTH_YEAR'
df["Date"] = pd.to_datetime(df.BILL_MONTH_YEAR, format='%b-%y')

# Define summer months (replace with your definition if needed)
summer_months = set(['Jun', 'Jul', 'Aug'])

# Extract year information from 'Date'
df['Year'] = df['Date'].dt.year

# Calculate start and end dates for summer each year
summer_start = pd.to_datetime([f'{year}-06-01' for year in df['Year'].unique()])
summer_end = pd.to_datetime([f'{year}-08-31' for year in df['Year'].unique()])

# Plot the data with markers
plt.plot(df.Date, df.TOTAL_USAGE_COL, marker='o', linestyle='-');

# Plot vertical lines for summer start and end (using 'axvline')
for start, end in zip(summer_start, summer_end):
  plt.axvline(x=start, color='r', linestyle='--')
  plt.axvline(x=end, color='r', linestyle='--')

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Usage (McF)")
plt.xticks(rotation=45)
plt.legend()
plt.title("Consumer Usage, 2022-2025")

plt.show()
# Out:
# C:\Users\marke\AppData\Local\Temp\ipykernel_9500\3789476751.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# **From here it's pretty clear that there is a clean dropoff for the summer months. This makes sense between the gas system is automatic. From here, a logical goal for improving sustainability and costs is to simply reduce usage.**
